# %%
import requests
import tkinter as tk
from tkinter import messagebox
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.font_manager as fm

API_KEY = "0223db48f9b941f3a13b6ffa842607aa"
BASE_URL = "https://api.worldnewsapi.com/search-news"

print("Welcome to World News API")
searchItem = input("Input keywords or phrases: ")

queryData = {
    "api-key": API_KEY,
    "text" : f"\"{searchItem}\"",
    "text-match-indexes" : "title,content",
    "language" : "en",
}

response = requests.get(BASE_URL, params=queryData)

if response.status_code == 200:
    print(f"There are {response.json()["available"]} articles available with your query")
# Out:
# Welcome to World News API
# There are 231 articles available with your query
